# %% [markdown]
# ## Análisis de archivo olympic_results.PKL
# ### Objetivo:
# - Leer archivo PKL olympic_results.pkl y compararlo con archivo CSV con el mismo nombre

# %%
# %pip install numpy==1.26.4 pandas==2.2.2
# Out:
# Requirement already satisfied: numpy==1.26.4 in /Users/cdelatorre/Documents/GitHub/obligatorio_olimpiadas/.venv/lib/python3.10/site-packages (1.26.4)
# Requirement already satisfied: pandas==2.2.2 in /Users/cdelatorre/Documents/GitHub/obligatorio_olimpiadas/.venv/lib/python3.10/site-packages (2.2.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/cdelatorre/Documents/GitHub/obligatorio_olimpiadas/.venv/lib/python3.10/site-packages (from pandas==2.2.2) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/cdelatorre/Documents/GitHub/obligatorio_olimpiadas/.venv/lib/python3.10/site-packages (from pandas==2.2.2) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/cdelatorre/Documents/GitHub/obligatorio_olimpiadas/.venv/lib/python3.10/site-packages (from pandas==2.2.2) (2024.1)
# Requirement already satisfied: six>=1.5 in /Users/cdelatorre/Documents/GitHub/obligatorio_olimpiadas/.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas==2.2.2) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np

print("numpy version:", np.__version__)
print("pandas version:", pd.__version__)
# Out:
# numpy version: 1.26.4
# pandas version: 2.2.2

# %%
# CSV olympic_results
df_csv = pd.read_csv('datos/landing/olympic_results.csv')
df_csv
# Out:
#            discipline_title  \
# 0                   Curling
# 1                   Curling
# 2                   Curling
# 3                   Curling
# 4                   Curling
# ...                     ...
# 162799          Ski Jumping
# 162800          Ski Jumping
# 162801          Ski Jumping
# 162802          Ski Jumping
# 162803  Gymnastics Artistic
#
#                                               event_title      slug_game  \
# 0                                           Mixed Doubles   beijing-2022
# 1                                           Mixed Doubles   beijing-2022
# 2                                           Mixed Doubles   beijing-2022
# 3                                           Mixed Doubles   beijing-2022
# 4                                           Mixed Doubles   beijing-2022
# ...                                                   ...            ...
# 162799                         Normal Hill Individual men  chamonix-1924
# 162800                         Normal Hill Individual men  chamonix-1924
# 162801                         Normal Hill Individual men  chamonix-1924
# 162802                         Normal Hill Individual men  chamonix-1924
# 162803  26th Federal Festival, Society and Association...     paris-1900
#
#        participant_type medal_type  \
# 0              GameTeam       GOLD
# 1              GameTeam     SILVER
# 2              GameTeam     BRONZE
# 3              GameTeam        NaN
# 4              GameTeam        NaN
# ...                 ...        ...
# 162799          Athlete        NaN
# 162800          Athlete        NaN
# 162801          Athlete        NaN
# 162802          Athlete        NaN
# 162803         GameTeam        NaN
#
#                                                  athletes rank_equal  \
# 0       [('Stefania CONSTANTINI', 'https://olympics.co...      False
# 1       [('Kristin SKASLIEN', 'https://olympics.com/en...      False
# 2       [('Almida DE VAL', 'https://olympics.com/en/at...      False
# 3       [('Jennifer DODDS', 'https://olympics.com/en/a...      False
# 4       [('Rachel HOMAN', 'https://olympics.com/en/ath...      False
# ...                                                   ...        ...
# 162799                                                NaN        NaN
# 162800                                                NaN        NaN
# 162801                                                NaN        NaN
# 162802                                                NaN        NaN
# 162803                                                NaN        NaN
#
#        rank_position              country_name country_code  \
# 0                  1                     Italy           IT
# 1                  2                    Norway           NO
# 2                  3                    Sweden           SE
# 3                  4             Great Britain           GB
# 4                  5                    Canada           CA
# ...              ...                       ...          ...
# 162799           DNS                    Poland           PL
# 162800           DNS                    Poland           PL
# 162801           DNS            Czechoslovakia         CSHH
# 162802           DNS  United States of America           US
# 162803             1                    France           FR
#
#        country_3_letter_code  \
# 0                        ITA
# 1                        NOR
# 2                        SWE
# 3                        GBR
# 4                        CAN
# ...                      ...
# 162799                   POL
# 162800                   POL
# 162801                   TCH
# 162802                   USA
# 162803                   FRA
#
#                                               athlete_url   athlete_full_name  \
# 0                                                     NaN                 NaN
# 1                                                     NaN                 NaN
# 2                                                     NaN                 NaN
# 3                                                     NaN                 NaN
# 4                                                     NaN                 NaN
# ...                                                   ...                 ...
# 162799  https://olympics.com/en/athletes/franciszek-bujak    Franciszek BUJAK
# 162800                                                NaN  Henryk Mückenbrunn
# 162801                                                NaN      Milda Prokopec
# 162802                                                NaN       Sigurd Overby
# 162803                                                NaN                 NaN
#
#        value_unit value_type
# 0             NaN        NaN
# 1             NaN        NaN
# 2             NaN        NaN
# 3             NaN        NaN
# 4             NaN        NaN
# ...           ...        ...
# 162799        NaN        IRM
# 162800        NaN        IRM
# 162801        NaN        IRM
# 162802        NaN        IRM
# 162803    142 pts     POINTS
#
# [162804 rows x 15 columns]

# %%
# Pickle olympic_results
df_pkl = pd.read_pickle('datos/landing/olympic_results.pkl')
df_pkl
# Out:
#         discipline_title                                        event_title  \
# 0                Curling                                      Mixed Doubles
# 1                Curling                                      Mixed Doubles
# 2                Curling                                      Mixed Doubles
# 3                Curling                                      Mixed Doubles
# 4                Curling                                      Mixed Doubles
# ..                   ...                                                ...
# 202          Ski Jumping                         Normal Hill Individual men
# 203          Ski Jumping                         Normal Hill Individual men
# 204          Ski Jumping                         Normal Hill Individual men
# 205          Ski Jumping                         Normal Hill Individual men
# 206  Gymnastics Artistic  26th Federal Festival, Society and Association...
#
#          slug_game participant_type medal_type  \
# 0     beijing-2022         GameTeam       GOLD
# 1     beijing-2022         GameTeam     SILVER
# 2     beijing-2022         GameTeam     BRONZE
# 3     beijing-2022         GameTeam       None
# 4     beijing-2022         GameTeam       None
# ..             ...              ...        ...
# 202  chamonix-1924          Athlete       None
# 203  chamonix-1924          Athlete       None
# 204  chamonix-1924          Athlete       None
# 205  chamonix-1924          Athlete       None
# 206     paris-1900         GameTeam       None
#
#                                               athletes rank_equal  \
# 0    [(Stefania CONSTANTINI, https://olympics.com/e...      False
# 1    [(Kristin SKASLIEN, https://olympics.com/en/at...      False
# 2    [(Almida DE VAL, https://olympics.com/en/athle...      False
# 3    [(Jennifer DODDS, https://olympics.com/en/athl...      False
# 4    [(Rachel HOMAN, https://olympics.com/en/athlet...      False
# ..                                                 ...        ...
# 202                                                NaN       None
# 203                                                NaN       None
# 204                                                NaN       None
# 205                                                NaN       None
# 206                                                NaN       None
#
#     rank_position              country_name country_code  \
# 0               1                     Italy           IT
# 1               2                    Norway           NO
# 2               3                    Sweden           SE
# 3               4             Great Britain           GB
# 4               5                    Canada           CA
# ..            ...                       ...          ...
# 202           DNS                    Poland           PL
# 203           DNS                    Poland           PL
# 204           DNS            Czechoslovakia         CSHH
# 205           DNS  United States of America           US
# 206             1                    France           FR
#
#     country_3_letter_code                                        athlete_url  \
# 0                     ITA                                                NaN
# 1                     NOR                                                NaN
# 2                     SWE                                                NaN
# 3                     GBR                                                NaN
# 4                     CAN                                                NaN
# ..                    ...                                                ...
# 202                   POL  https://olympics.com/en/athletes/franciszek-bujak
# 203                   POL                                               None
# 204                   TCH                                               None
# 205                   USA                                               None
# 206                   FRA                                                NaN
#
#       athlete_full_name value_unit value_type
# 0                   NaN        NaN        NaN
# 1                   NaN        NaN        NaN
# 2                   NaN        NaN        NaN
# 3                   NaN        NaN        NaN
# 4                   NaN        NaN        NaN
# ..                  ...        ...        ...
# 202    Franciszek BUJAK       None        IRM
# 203  Henryk Mückenbrunn       None        IRM
# 204      Milda Prokopec       None        IRM
# 205       Sigurd Overby       None        IRM
# 206                 NaN    142 pts     POINTS
#
# [162804 rows x 15 columns]

# %%
def analizar_df(df):
    # Crear una lista para almacenar el resumen de las columnas
    resumen_data = []

    for col in df.columns:
        nombre = col
        tipo = df[col].dtype
        cantidad_valores = len(df[col])
        valores_unicos = df[col].apply(lambda x: str(x) if isinstance(x, list) else x).nunique()
        nulos = df[col].isnull().sum()
        strings_vacios = df[col].apply(lambda x: x == '').sum() if df[col].dtype == 'object' else 0

        # Tratar de obtener el valor más frecuente
        try:
            mas_frecuente = df[col].mode().iloc[0] if not df[col].mode().empty else None
        except TypeError:
            mas_frecuente = None

        # Tratar de obtener el valor menos frecuente
        try:
            menos_frecuente = df[col].value_counts().idxmin() if not df[col].value_counts().empty else None
        except TypeError:
            menos_frecuente = None

        # Añadir la información de la columna al resumen
        resumen_data.append({
            'Nombre': nombre,
            'Tipo': tipo,
            'Cantidad de Valores': cantidad_valores,
            'Valores Únicos': valores_unicos,
            'Nulos': nulos,
            'Strings Vacíos': strings_vacios,
            'Más Frecuente': mas_frecuente,
            'Menos Frecuente': menos_frecuente
        })

    # Convertir la lista de resumen a un DataFrame
    resumen = pd.DataFrame(resumen_data)

    # Devolver el resumen
    return resumen

# %%
analizar_df(df_csv)
# Out:
#                    Nombre    Tipo  Cantidad de Valores  Valores Únicos  \
# 0        discipline_title  object               162804              86
# 1             event_title  object               162804            1567
# 2               slug_game  object               162804              53
# 3        participant_type  object               162804               2
# 4              medal_type  object               162804               3
# 5                athletes  object               162804            6845
# 6              rank_equal  object               162804               2
# 7           rank_position  object               162804             193
# 8            country_name  object               162804             238
# 9            country_code  object               162804             213
# 10  country_3_letter_code  object               162804             233
# 11            athlete_url  object               162804           68104
# 12      athlete_full_name  object               162804           75263
# 13             value_unit  object               162804           46475
# 14             value_type  object               162804              12
#
#      Nulos  Strings Vacíos                                      Más Frecuente  \
# 0        0               0                                          Athletics
# 1        0               0                                   individual mixed
# 2        0               0                                           rio-2016
# 3        0               0                                            Athlete
# 4   142598               0                                             BRONZE
# 5   154828               0  [('LETOT LETOT', 'https://olympics.com/en/athl...
# 6   130278               0                                               True
# 7     3878               0                                                  9
# 8        0               0                           United States of America
# 9     5036               0                                                 US
# 10       0               0                                                USA
# 11   32813               0  https://olympics.com/en/athletes/heikki-savola...
# 12   21158               0                                  Heikki SAVOLAINEN
# 13   84158               0                                          same time
# 14   72755               0                                               TIME
#
#                                       Menos Frecuente
# 0                                       Basque Pelota
# 1                                          double men
# 2                                       chamonix-1924
# 3                                            GameTeam
# 4                                              SILVER
# 5   [('Domingo Torralva', None), ('Luis Torralva',...
# 6                                               False
# 7                                                 DQB
# 8                                         South Sudan
# 9                                                  SS
# 10                                                SSD
# 11      https://olympics.com/en/athletes/peter-jonson
# 12                                   Hanspeter HASLER
# 13                                             511850
# 14                                         IRM_POINTS

# %%
analizar_df(df_pkl)
# Out:
#                    Nombre    Tipo  Cantidad de Valores  Valores Únicos  \
# 0        discipline_title  object               162804              86
# 1             event_title  object               162804            1567
# 2               slug_game  object               162804              53
# 3        participant_type  object               162804               2
# 4              medal_type  object               162804               3
# 5                athletes  object               162804            6845
# 6              rank_equal  object               162804               2
# 7           rank_position  object               162804             193
# 8            country_name  object               162804             238
# 9            country_code  object               162804             215
# 10  country_3_letter_code  object               162804             233
# 11            athlete_url  object               162804           68105
# 12      athlete_full_name  object               162804           75263
# 13             value_unit  object               162804           46476
# 14             value_type  object               162804              12
#
#      Nulos  Strings Vacíos                                      Más Frecuente  \
# 0        0               0                                          Athletics
# 1        0               0                                   individual mixed
# 2        0               0                                           rio-2016
# 3        0               0                                            Athlete
# 4   142598               0                                             BRONZE
# 5   154828               0  [(LETOT LETOT, https://olympics.com/en/athlete...
# 6   130278               0                                               True
# 7     3878               0                                                  9
# 8        0               0                           United States of America
# 9        0            4964                                                 US
# 10       0               0                                                USA
# 11   32811               2  https://olympics.com/en/athletes/heikki-savola...
# 12   21158               0                                  Heikki SAVOLAINEN
# 13   82288            1870
# 14   72755               0                                               TIME
#
#                                       Menos Frecuente
# 0                                       Basque Pelota
# 1                                          double men
# 2                                       chamonix-1924
# 3                                            GameTeam
# 4                                              SILVER
# 5   [(Domingo Torralva, None), (Luis Torralva, None)]
# 6                                               False
# 7                                                 DQB
# 8                                         South Sudan
# 9                                                  SS
# 10                                                SSD
# 11  https://olympics.com/en/athletes/nicolae-crist...
# 12                                   Hanspeter HASLER
# 13                                             246970
# 14                                         IRM_POINTS

# %% [markdown]
# Observamos diferencias en la cantidad de nulos y cadenas vacías.
# Decidimos reemplazar los valores nulos por cadenas vacías para mantener un criterio en común entre los dos DataFrames

# %%
# Reemplazar valores nulos por strings vacíos en todas las columnas
df_csv = df_csv.fillna('')

# %%
# Reemplazar valores nulos por strings vacíos en todas las columnas
df_pkl = df_pkl.fillna('')

# %%
analizar_csv_resultado = analizar_df(df_csv)
analizar_csv_resultado
# Out:
#                    Nombre    Tipo  Cantidad de Valores  Valores Únicos  Nulos  \
# 0        discipline_title  object               162804              86      0
# 1             event_title  object               162804            1567      0
# 2               slug_game  object               162804              53      0
# 3        participant_type  object               162804               2      0
# 4              medal_type  object               162804               4      0
# 5                athletes  object               162804            6846      0
# 6              rank_equal  object               162804               3      0
# 7           rank_position  object               162804             194      0
# 8            country_name  object               162804             238      0
# 9            country_code  object               162804             214      0
# 10  country_3_letter_code  object               162804             233      0
# 11            athlete_url  object               162804           68105      0
# 12      athlete_full_name  object               162804           75264      0
# 13             value_unit  object               162804           46476      0
# 14             value_type  object               162804              13      0
#
#     Strings Vacíos             Más Frecuente  \
# 0                0                 Athletics
# 1                0          individual mixed
# 2                0                  rio-2016
# 3                0                   Athlete
# 4           142598
# 5           154828
# 6           130278
# 7             3878                         9
# 8                0  United States of America
# 9             5036                        US
# 10               0                       USA
# 11           32813
# 12           21158
# 13           84158
# 14           72755
#
#                                       Menos Frecuente
# 0                                       Basque Pelota
# 1                                          double men
# 2                                       chamonix-1924
# 3                                            GameTeam
# 4                                              SILVER
# 5   [('Domingo Torralva', None), ('Luis Torralva',...
# 6                                               False
# 7                                                 YCD
# 8                                         South Sudan
# 9                                                  SS
# 10                                                SSD
# 11    https://olympics.com/en/athletes/antonio-handal
# 12                                      Andrea ANACAN
# 13                                             231130
# 14                                         IRM_POINTS

# %%
analizar_pkl_resultado = analizar_df(df_pkl)
analizar_pkl_resultado
# Out:
#                    Nombre    Tipo  Cantidad de Valores  Valores Únicos  Nulos  \
# 0        discipline_title  object               162804              86      0
# 1             event_title  object               162804            1567      0
# 2               slug_game  object               162804              53      0
# 3        participant_type  object               162804               2      0
# 4              medal_type  object               162804               4      0
# 5                athletes  object               162804            6846      0
# 6              rank_equal  object               162804               3      0
# 7           rank_position  object               162804             194      0
# 8            country_name  object               162804             238      0
# 9            country_code  object               162804             215      0
# 10  country_3_letter_code  object               162804             233      0
# 11            athlete_url  object               162804           68105      0
# 12      athlete_full_name  object               162804           75264      0
# 13             value_unit  object               162804           46476      0
# 14             value_type  object               162804              13      0
#
#     Strings Vacíos             Más Frecuente  \
# 0                0                 Athletics
# 1                0          individual mixed
# 2                0                  rio-2016
# 3                0                   Athlete
# 4           142598
# 5           154828
# 6           130278
# 7             3878                         9
# 8                0  United States of America
# 9             4964                        US
# 10               0                       USA
# 11           32813
# 12           21158
# 13           84158
# 14           72755
#
#                                       Menos Frecuente
# 0                                       Basque Pelota
# 1                                          double men
# 2                                       chamonix-1924
# 3                                            GameTeam
# 4                                              SILVER
# 5   [(Domingo Torralva, None), (Luis Torralva, None)]
# 6                                               False
# 7                                                 YCD
# 8                                         South Sudan
# 9                                                  SS
# 10                                                SSD
# 11    https://olympics.com/en/athletes/antonio-handal
# 12                                      Andrea ANACAN
# 13                                             231130
# 14                                         IRM_POINTS

# %% [markdown]
# Evaluamos las diferencias que continúan entre los dos data frames

# %%
# Reset index y alinear - los DataFrames deben estar alineados correctamente antes de compararlos
df_csv_reset = df_csv.reset_index(drop=True)
df_pkl_reset = df_pkl.reset_index(drop=True)

df_csv_aligned, df_pkl_aligned = df_csv_reset.align(df_pkl_reset)

# %%
diferencias_analisis = analizar_csv_resultado.compare(analizar_pkl_resultado)
# Identificar las filas completas con diferencias
differences_indices = diferencias_analisis.index
df_csv_diff = analizar_csv_resultado.loc[differences_indices]
df_pkl_diff = analizar_pkl_resultado.loc[differences_indices]

# %%
# Mostrar las filas completas con diferencias
print("En el DataFrame CSV:")
df_csv_diff
# Out:
# En el DataFrame CSV:
#          Nombre    Tipo  Cantidad de Valores  Valores Únicos  Nulos  \
# 5      athletes  object               162804            6846      0
# 9  country_code  object               162804             214      0
#
#    Strings Vacíos Más Frecuente  \
# 5          154828
# 9            5036            US
#
#                                      Menos Frecuente
# 5  [('Domingo Torralva', None), ('Luis Torralva',...
# 9                                                 SS

# %%
print("En el DataFrame PKL:")
df_pkl_diff
# Out:
# En el DataFrame PKL:
#          Nombre    Tipo  Cantidad de Valores  Valores Únicos  Nulos  \
# 5      athletes  object               162804            6846      0
# 9  country_code  object               162804             215      0
#
#    Strings Vacíos Más Frecuente  \
# 5          154828
# 9            4964            US
#
#                                      Menos Frecuente
# 5  [(Domingo Torralva, None), (Luis Torralva, None)]
# 9                                                 SS

# %%
def comparar_columnas(df1, df2):
    """
    Compara las columnas de dos DataFrames y muestra las diferencias.

    Args:
        df1 (pd.DataFrame): Primer DataFrame a comparar.
        df2 (pd.DataFrame): Segundo DataFrame a comparar.
    """
    # Verificar si ambos DataFrames tienen las mismas columnas
    if not df1.columns.equals(df2.columns):
        print("Los DataFrames no tienen las mismas columnas.")
        return

    for column in df1.columns:
        # Normalizar listas y tuplas en las columnas que contienen listas o tuplas
        if df1[column].apply(lambda x: isinstance(x, (list, tuple))).any():
            col1 = df1[column].apply(lambda x: sorted(x) if isinstance(x, (list, tuple)) else x)
            col2 = df2[column].apply(lambda x: sorted(x) if isinstance(x, (list, tuple)) else x)
            col1 = col1.apply(lambda x: str(x) if isinstance(x, (list, tuple)) else x)
            col2 = col2.apply(lambda x: str(x) if isinstance(x, (list, tuple)) else x)
        else:
            col1 = df1[column]
            col2 = df2[column]

        if col1.equals(col2):
            print(f"La columna '{column}' es idéntica en ambos DataFrames.")
        else:
            print(f"Diferencias encontradas en la columna '{column}':")
            differences = col1.compare(col2)
            print(differences)

# %%
comparar_columnas(df_csv_aligned, df_pkl_aligned)
# Out:
# La columna 'discipline_title' es idéntica en ambos DataFrames.
# La columna 'event_title' es idéntica en ambos DataFrames.
# La columna 'slug_game' es idéntica en ambos DataFrames.
# La columna 'participant_type' es idéntica en ambos DataFrames.
# La columna 'medal_type' es idéntica en ambos DataFrames.
# Diferencias encontradas en la columna 'athletes':
#                                                      self  \
# 0       [('Stefania CONSTANTINI', 'https://olympics.co...
# 1       [('Kristin SKASLIEN', 'https://olympics.com/en...
# 2       [('Almida DE VAL', 'https://olympics.com/en/at...
# 3       [('Jennifer DODDS', 'https://olympics.com/en/a...
# 4       [('Rachel HOMAN', 'https://olympics.com/en/ath...
# ...                                                   ...
# 162758  [('Isabella RIZZI', 'https://olympics.com/en/a...
# 162759  [('Judi GENOVESI', 'https://olympics.com/en/at...
# 162760  [('Stefania BERTELE', 'https://olympics.com/en...
# 162761  [('Susan KELLEY', 'https://olympics.com/en/ath...
# 162762  [('Susanne HANDSCHMANN', 'https://olympics.com...
#
#                                                     other
# 0       [(Stefania CONSTANTINI, https://olympics.com/e...
# 1       [(Kristin SKASLIEN, https://olympics.com/en/at...
# 2       [(Almida DE VAL, https://olympics.com/en/athle...
# 3       [(Jennifer DODDS, https://olympics.com/en/athl...
# 4       [(Rachel HOMAN, https://olympics.com/en/athlet...
# ...                                                   ...
# 162758  [(Isabella RIZZI, https://olympics.com/en/athl...
# 162759  [(Judi GENOVESI, https://olympics.com/en/athle...
# 162760  [(Stefania BERTELE, https://olympics.com/en/at...
# 162761  [(Susan KELLEY, https://olympics.com/en/athlet...
# 162762  [(Susanne HANDSCHMANN, https://olympics.com/en...
#
# [7976 rows x 2 columns]
# La columna 'rank_equal' es idéntica en ambos DataFrames.
# La columna 'rank_position' es idéntica en ambos DataFrames.
# La columna 'country_name' es idéntica en ambos DataFrames.
# Diferencias encontradas en la columna 'country_code':
#       self other
# 4780          NA
# 4964          NA
# 5282          NA
# 5877          NA
# 8886          NA
# ...    ...   ...
# 82057         NA
# 82483         NA
# 82689         NA
# 82861         NA
# 82917         NA
#
# [72 rows x 2 columns]
# La columna 'country_3_letter_code' es idéntica en ambos DataFrames.
# La columna 'athlete_url' es idéntica en ambos DataFrames.
# La columna 'athlete_full_name' es idéntica en ambos DataFrames.
# La columna 'value_unit' es idéntica en ambos DataFrames.
# La columna 'value_type' es idéntica en ambos DataFrames.

# %% [markdown]
# Se observan diferencias en las columnas 'athletes' y 'country_code'.

# %%
#Evaluamos country_code
csv_country_code = df_csv_aligned['country_code']
pkl_country_code = df_pkl_aligned['country_code']

print(f"Diferencias encontradas en la columna 'country_code':")
diferencia_cc = csv_country_code.compare(pkl_country_code)
print(f"{len(diferencia_cc)} filas")
diferencia_cc
# Out:
# Diferencias encontradas en la columna 'country_code':
# 72 filas
#       self other
# 4780          NA
# 4964          NA
# 5282          NA
# 5877          NA
# 8886          NA
# ...    ...   ...
# 82057         NA
# 82483         NA
# 82689         NA
# 82861         NA
# 82917         NA
#
# [72 rows x 2 columns]

# %%
# Identificar las filas completas con diferencias de country_code
diferencia_cc_indices = diferencia_cc.index
df_csv_diff_cc = df_csv_aligned.loc[diferencia_cc_indices]
df_pkl_diff_cc = df_pkl_aligned.loc[diferencia_cc_indices]

# %%
# Mostrar las filas completas con diferencias
print("En el DataFrame CSV:")
df_csv_diff_cc
# Out:
# En el DataFrame CSV:
#         discipline_title            event_title       slug_game  \
# 4780        Cycling Road      Women's Road Race      tokyo-2020
# 4964        Cycling Road        Men's Road Race      tokyo-2020
# 5282              Boxing  Men's Light (57-63kg)      tokyo-2020
# 5877   Marathon Swimming             Men's 10km      tokyo-2020
# 8886           Athletics         Men's Marathon      tokyo-2020
# ...                  ...                    ...             ...
# 82057           Swimming   100m butterfly women  barcelona-1992
# 82483           Swimming   100m freestyle women  barcelona-1992
# 82689           Swimming  200m breaststroke men  barcelona-1992
# 82861           Swimming    50m freestyle women  barcelona-1992
# 82917           Swimming  100m breaststroke men  barcelona-1992
#
#       participant_type medal_type athletes rank_equal rank_position  \
# 4780           Athlete                          False           DNF
# 4964           Athlete                          False           DNF
# 5282           Athlete                           True             9
# 5877           Athlete                          False            16
# 8886           Athlete                          False            42
# ...                ...        ...      ...        ...           ...
# 82057          Athlete                                           46
# 82483          Athlete                                           35
# 82689          Athlete                                           40
# 82861          Athlete                                           37
# 82917          Athlete                                           43
#
#       country_name country_code country_3_letter_code  \
# 4780       Namibia                                NAM
# 4964       Namibia                                NAM
# 5282       Namibia                                NAM
# 5877       Namibia                                NAM
# 8886       Namibia                                NAM
# ...            ...          ...                   ...
# 82057      Namibia                                NAM
# 82483      Namibia                                NAM
# 82689      Namibia                                NAM
# 82861      Namibia                                NAM
# 82917      Namibia                                NAM
#
#                                              athlete_url  \
# 4780        https://olympics.com/en/athletes/vera-adrian
# 4964   https://olympics.com/en/athletes/tristan-de-lange
# 5282   https://olympics.com/en/athletes/jonas-junias-...
# 5877    https://olympics.com/en/athletes/phillip-seidler
# 8886   https://olympics.com/en/athletes/tomas-hilifa-...
# ...                                                  ...
# 82057  https://olympics.com/en/athletes/monica-anja-dahl
# 82483  https://olympics.com/en/athletes/monica-anja-dahl
# 82689   https://olympics.com/en/athletes/jorg-lindemeier
# 82861  https://olympics.com/en/athletes/monica-anja-dahl
# 82917   https://olympics.com/en/athletes/jorg-lindemeier
#
#            athlete_full_name value_unit value_type
# 4780             Vera ADRIAN                   IRM
# 4964        Tristan DE LANGE                   IRM
# 5282      Jonas Junias JONAS
# 5877         Phillip SEIDLER  1:53:14.1       TIME
# 8886   Tomas Hilifa RAINHOLD
# ...                      ...        ...        ...
# 82057       Monica Anja DAHL
# 82483       Monica Anja DAHL
# 82689        Jörg LINDEMEIER
# 82861       Monica Anja DAHL
# 82917        Jörg LINDEMEIER
#
# [72 rows x 15 columns]

# %%
print("En el DataFrame PKL:")
df_pkl_diff_cc
# Out:
# En el DataFrame PKL:
#         discipline_title            event_title       slug_game  \
# 4780        Cycling Road      Women's Road Race      tokyo-2020
# 4964        Cycling Road        Men's Road Race      tokyo-2020
# 5282              Boxing  Men's Light (57-63kg)      tokyo-2020
# 5877   Marathon Swimming             Men's 10km      tokyo-2020
# 8886           Athletics         Men's Marathon      tokyo-2020
# ...                  ...                    ...             ...
# 82057           Swimming   100m butterfly women  barcelona-1992
# 82483           Swimming   100m freestyle women  barcelona-1992
# 82689           Swimming  200m breaststroke men  barcelona-1992
# 82861           Swimming    50m freestyle women  barcelona-1992
# 82917           Swimming  100m breaststroke men  barcelona-1992
#
#       participant_type medal_type athletes rank_equal rank_position  \
# 4780           Athlete                          False           DNF
# 4964           Athlete                          False           DNF
# 5282           Athlete                           True             9
# 5877           Athlete                          False            16
# 8886           Athlete                          False            42
# ...                ...        ...      ...        ...           ...
# 82057          Athlete                                           46
# 82483          Athlete                                           35
# 82689          Athlete                                           40
# 82861          Athlete                                           37
# 82917          Athlete                                           43
#
#       country_name country_code country_3_letter_code  \
# 4780       Namibia           NA                   NAM
# 4964       Namibia           NA                   NAM
# 5282       Namibia           NA                   NAM
# 5877       Namibia           NA                   NAM
# 8886       Namibia           NA                   NAM
# ...            ...          ...                   ...
# 82057      Namibia           NA                   NAM
# 82483      Namibia           NA                   NAM
# 82689      Namibia           NA                   NAM
# 82861      Namibia           NA                   NAM
# 82917      Namibia           NA                   NAM
#
#                                              athlete_url  \
# 4780        https://olympics.com/en/athletes/vera-adrian
# 4964   https://olympics.com/en/athletes/tristan-de-lange
# 5282   https://olympics.com/en/athletes/jonas-junias-...
# 5877    https://olympics.com/en/athletes/phillip-seidler
# 8886   https://olympics.com/en/athletes/tomas-hilifa-...
# ...                                                  ...
# 82057  https://olympics.com/en/athletes/monica-anja-dahl
# 82483  https://olympics.com/en/athletes/monica-anja-dahl
# 82689   https://olympics.com/en/athletes/jorg-lindemeier
# 82861  https://olympics.com/en/athletes/monica-anja-dahl
# 82917   https://olympics.com/en/athletes/jorg-lindemeier
#
#            athlete_full_name value_unit value_type
# 4780             Vera ADRIAN                   IRM
# 4964        Tristan DE LANGE                   IRM
# 5282      Jonas Junias JONAS
# 5877         Phillip SEIDLER  1:53:14.1       TIME
# 8886   Tomas Hilifa RAINHOLD
# ...                      ...        ...        ...
# 82057       Monica Anja DAHL
# 82483       Monica Anja DAHL
# 82689        Jörg LINDEMEIER
# 82861       Monica Anja DAHL
# 82917        Jörg LINDEMEIER
#
# [72 rows x 15 columns]

# %%
comparar_columnas(df_csv_diff_cc, df_pkl_diff_cc)
# Out:
# La columna 'discipline_title' es idéntica en ambos DataFrames.
# La columna 'event_title' es idéntica en ambos DataFrames.
# La columna 'slug_game' es idéntica en ambos DataFrames.
# La columna 'participant_type' es idéntica en ambos DataFrames.
# La columna 'medal_type' es idéntica en ambos DataFrames.
# La columna 'athletes' es idéntica en ambos DataFrames.
# La columna 'rank_equal' es idéntica en ambos DataFrames.
# La columna 'rank_position' es idéntica en ambos DataFrames.
# La columna 'country_name' es idéntica en ambos DataFrames.
# Diferencias encontradas en la columna 'country_code':
#       self other
# 4780          NA
# 4964          NA
# 5282          NA
# 5877          NA
# 8886          NA
# ...    ...   ...
# 82057         NA
# 82483         NA
# 82689         NA
# 82861         NA
# 82917         NA
#
# [72 rows x 2 columns]
# La columna 'country_3_letter_code' es idéntica en ambos DataFrames.
# La columna 'athlete_url' es idéntica en ambos DataFrames.
# La columna 'athlete_full_name' es idéntica en ambos DataFrames.
# La columna 'value_unit' es idéntica en ambos DataFrames.
# La columna 'value_type' es idéntica en ambos DataFrames.

# %%
df_csv_diff_cc[['country_name', 'country_code', 'country_3_letter_code']]
# Out:
#       country_name country_code country_3_letter_code
# 4780       Namibia                                NAM
# 4964       Namibia                                NAM
# 5282       Namibia                                NAM
# 5877       Namibia                                NAM
# 8886       Namibia                                NAM
# ...            ...          ...                   ...
# 82057      Namibia                                NAM
# 82483      Namibia                                NAM
# 82689      Namibia                                NAM
# 82861      Namibia                                NAM
# 82917      Namibia                                NAM
#
# [72 rows x 3 columns]

# %%
df_pkl_diff_cc[['country_name', 'country_code', 'country_3_letter_code']]
# Out:
#       country_name country_code country_3_letter_code
# 4780       Namibia           NA                   NAM
# 4964       Namibia           NA                   NAM
# 5282       Namibia           NA                   NAM
# 5877       Namibia           NA                   NAM
# 8886       Namibia           NA                   NAM
# ...            ...          ...                   ...
# 82057      Namibia           NA                   NAM
# 82483      Namibia           NA                   NAM
# 82689      Namibia           NA                   NAM
# 82861      Namibia           NA                   NAM
# 82917      Namibia           NA                   NAM
#
# [72 rows x 3 columns]

# %% [markdown]
# Observamos diferencias para el código del país "Namibia", probablemente causadas por la coincidencia con "Not Available" de Python. Decidimos aplicar el código de país "NA" a todas las filas con país "Namibia" en el df proveniente del CSV

# %%
df_csv_aligned.loc[df_csv_aligned['country_name'] == 'Namibia', 'country_code'] = 'NA'

# %%
comparar_columnas(df_csv_aligned, df_pkl_aligned)
# Out:
# La columna 'discipline_title' es idéntica en ambos DataFrames.
# La columna 'event_title' es idéntica en ambos DataFrames.
# La columna 'slug_game' es idéntica en ambos DataFrames.
# La columna 'participant_type' es idéntica en ambos DataFrames.
# La columna 'medal_type' es idéntica en ambos DataFrames.
# Diferencias encontradas en la columna 'athletes':
#                                                      self  \
# 0       [('Stefania CONSTANTINI', 'https://olympics.co...
# 1       [('Kristin SKASLIEN', 'https://olympics.com/en...
# 2       [('Almida DE VAL', 'https://olympics.com/en/at...
# 3       [('Jennifer DODDS', 'https://olympics.com/en/a...
# 4       [('Rachel HOMAN', 'https://olympics.com/en/ath...
# ...                                                   ...
# 162758  [('Isabella RIZZI', 'https://olympics.com/en/a...
# 162759  [('Judi GENOVESI', 'https://olympics.com/en/at...
# 162760  [('Stefania BERTELE', 'https://olympics.com/en...
# 162761  [('Susan KELLEY', 'https://olympics.com/en/ath...
# 162762  [('Susanne HANDSCHMANN', 'https://olympics.com...
#
#                                                     other
# 0       [(Stefania CONSTANTINI, https://olympics.com/e...
# 1       [(Kristin SKASLIEN, https://olympics.com/en/at...
# 2       [(Almida DE VAL, https://olympics.com/en/athle...
# 3       [(Jennifer DODDS, https://olympics.com/en/athl...
# 4       [(Rachel HOMAN, https://olympics.com/en/athlet...
# ...                                                   ...
# 162758  [(Isabella RIZZI, https://olympics.com/en/athl...
# 162759  [(Judi GENOVESI, https://olympics.com/en/athle...
# 162760  [(Stefania BERTELE, https://olympics.com/en/at...
# 162761  [(Susan KELLEY, https://olympics.com/en/athlet...
# 162762  [(Susanne HANDSCHMANN, https://olympics.com/en...
#
# [7976 rows x 2 columns]
# La columna 'rank_equal' es idéntica en ambos DataFrames.
# La columna 'rank_position' es idéntica en ambos DataFrames.
# La columna 'country_name' es idéntica en ambos DataFrames.
# La columna 'country_code' es idéntica en ambos DataFrames.
# La columna 'country_3_letter_code' es idéntica en ambos DataFrames.
# La columna 'athlete_url' es idéntica en ambos DataFrames.
# La columna 'athlete_full_name' es idéntica en ambos DataFrames.
# La columna 'value_unit' es idéntica en ambos DataFrames.
# La columna 'value_type' es idéntica en ambos DataFrames.

# %%
#Evaluamos athletes
csv_athletes = df_csv_aligned['athletes']
pkl_athletes = df_pkl_aligned['athletes']

print(f"Diferencias encontradas en la columna 'athletes':")
diferencia_at = csv_athletes.compare(pkl_athletes)
print(f"{len(diferencia_at)} filas")
diferencia_at
# Out:
# Diferencias encontradas en la columna 'athletes':
# 7976 filas
#                                                      self  \
# 0       [('Stefania CONSTANTINI', 'https://olympics.co...
# 1       [('Kristin SKASLIEN', 'https://olympics.com/en...
# 2       [('Almida DE VAL', 'https://olympics.com/en/at...
# 3       [('Jennifer DODDS', 'https://olympics.com/en/a...
# 4       [('Rachel HOMAN', 'https://olympics.com/en/ath...
# ...                                                   ...
# 162758  [('Isabella RIZZI', 'https://olympics.com/en/a...
# 162759  [('Judi GENOVESI', 'https://olympics.com/en/at...
# 162760  [('Stefania BERTELE', 'https://olympics.com/en...
# 162761  [('Susan KELLEY', 'https://olympics.com/en/ath...
# 162762  [('Susanne HANDSCHMANN', 'https://olympics.com...
#
#                                                     other
# 0       [(Stefania CONSTANTINI, https://olympics.com/e...
# 1       [(Kristin SKASLIEN, https://olympics.com/en/at...
# 2       [(Almida DE VAL, https://olympics.com/en/athle...
# 3       [(Jennifer DODDS, https://olympics.com/en/athl...
# 4       [(Rachel HOMAN, https://olympics.com/en/athlet...
# ...                                                   ...
# 162758  [(Isabella RIZZI, https://olympics.com/en/athl...
# 162759  [(Judi GENOVESI, https://olympics.com/en/athle...
# 162760  [(Stefania BERTELE, https://olympics.com/en/at...
# 162761  [(Susan KELLEY, https://olympics.com/en/athlet...
# 162762  [(Susanne HANDSCHMANN, https://olympics.com/en...
#
# [7976 rows x 2 columns]

# %%
# Identificar las filas completas con diferencias de athletes
diferencia_at_indices = diferencia_at.index
df_csv_diff_at = df_csv_aligned.loc[diferencia_at_indices]
df_pkl_diff_at = df_pkl_aligned.loc[diferencia_at_indices]

# %%
# Mostrar las filas completas con diferencias
print("En el DataFrame CSV:")
df_csv_diff_at
# Out:
# En el DataFrame CSV:
#        discipline_title        event_title       slug_game participant_type  \
# 0               Curling      Mixed Doubles    beijing-2022         GameTeam
# 1               Curling      Mixed Doubles    beijing-2022         GameTeam
# 2               Curling      Mixed Doubles    beijing-2022         GameTeam
# 3               Curling      Mixed Doubles    beijing-2022         GameTeam
# 4               Curling      Mixed Doubles    beijing-2022         GameTeam
# ...                 ...                ...             ...              ...
# 162758   Figure skating  Ice dancing mixed  innsbruck-1976         GameTeam
# 162759   Figure skating  Ice dancing mixed  innsbruck-1976         GameTeam
# 162760   Figure skating  Ice dancing mixed  innsbruck-1976         GameTeam
# 162761   Figure skating  Ice dancing mixed  innsbruck-1976         GameTeam
# 162762   Figure skating  Ice dancing mixed  innsbruck-1976         GameTeam
#
#        medal_type                                           athletes  \
# 0            GOLD  [('Stefania CONSTANTINI', 'https://olympics.co...
# 1          SILVER  [('Kristin SKASLIEN', 'https://olympics.com/en...
# 2          BRONZE  [('Almida DE VAL', 'https://olympics.com/en/at...
# 3                  [('Jennifer DODDS', 'https://olympics.com/en/a...
# 4                  [('Rachel HOMAN', 'https://olympics.com/en/ath...
# ...           ...                                                ...
# 162758             [('Isabella RIZZI', 'https://olympics.com/en/a...
# 162759             [('Judi GENOVESI', 'https://olympics.com/en/at...
# 162760             [('Stefania BERTELE', 'https://olympics.com/en...
# 162761             [('Susan KELLEY', 'https://olympics.com/en/ath...
# 162762             [('Susanne HANDSCHMANN', 'https://olympics.com...
#
#        rank_equal rank_position              country_name country_code  \
# 0           False             1                     Italy           IT
# 1           False             2                    Norway           NO
# 2           False             3                    Sweden           SE
# 3           False             4             Great Britain           GB
# 4           False             5                    Canada           CA
# ...           ...           ...                       ...          ...
# 162758                       14                     Italy           IT
# 162759                       15  United States of America           US
# 162760                       16                     Italy           IT
# 162761                       17  United States of America           US
# 162762                      DNF                   Austria           AT
#
#        country_3_letter_code athlete_url athlete_full_name value_unit  \
# 0                        ITA
# 1                        NOR
# 2                        SWE
# 3                        GBR
# 4                        CAN
# ...                      ...         ...               ...        ...
# 162758                   ITA                                    7×15+
# 162759                   USA                                    5×15+
# 162760                   ITA                                    8×16+
# 162761                   USA                                    9×17+
# 162762                   AUT
#
#        value_type
# 0
# 1
# 2
# 3
# 4
# ...           ...
# 162758       RANK
# 162759       RANK
# 162760       RANK
# 162761       RANK
# 162762        IRM
#
# [7976 rows x 15 columns]

# %%
print("En el DataFrame PKL:")
df_pkl_diff_at
# Out:
# En el DataFrame PKL:
#        discipline_title        event_title       slug_game participant_type  \
# 0               Curling      Mixed Doubles    beijing-2022         GameTeam
# 1               Curling      Mixed Doubles    beijing-2022         GameTeam
# 2               Curling      Mixed Doubles    beijing-2022         GameTeam
# 3               Curling      Mixed Doubles    beijing-2022         GameTeam
# 4               Curling      Mixed Doubles    beijing-2022         GameTeam
# ...                 ...                ...             ...              ...
# 162758   Figure skating  Ice dancing mixed  innsbruck-1976         GameTeam
# 162759   Figure skating  Ice dancing mixed  innsbruck-1976         GameTeam
# 162760   Figure skating  Ice dancing mixed  innsbruck-1976         GameTeam
# 162761   Figure skating  Ice dancing mixed  innsbruck-1976         GameTeam
# 162762   Figure skating  Ice dancing mixed  innsbruck-1976         GameTeam
#
#        medal_type                                           athletes  \
# 0            GOLD  [(Stefania CONSTANTINI, https://olympics.com/e...
# 1          SILVER  [(Kristin SKASLIEN, https://olympics.com/en/at...
# 2          BRONZE  [(Almida DE VAL, https://olympics.com/en/athle...
# 3                  [(Jennifer DODDS, https://olympics.com/en/athl...
# 4                  [(Rachel HOMAN, https://olympics.com/en/athlet...
# ...           ...                                                ...
# 162758             [(Isabella RIZZI, https://olympics.com/en/athl...
# 162759             [(Judi GENOVESI, https://olympics.com/en/athle...
# 162760             [(Stefania BERTELE, https://olympics.com/en/at...
# 162761             [(Susan KELLEY, https://olympics.com/en/athlet...
# 162762             [(Susanne HANDSCHMANN, https://olympics.com/en...
#
#        rank_equal rank_position              country_name country_code  \
# 0           False             1                     Italy           IT
# 1           False             2                    Norway           NO
# 2           False             3                    Sweden           SE
# 3           False             4             Great Britain           GB
# 4           False             5                    Canada           CA
# ...           ...           ...                       ...          ...
# 162758                       14                     Italy           IT
# 162759                       15  United States of America           US
# 162760                       16                     Italy           IT
# 162761                       17  United States of America           US
# 162762                      DNF                   Austria           AT
#
#        country_3_letter_code athlete_url athlete_full_name value_unit  \
# 0                        ITA
# 1                        NOR
# 2                        SWE
# 3                        GBR
# 4                        CAN
# ...                      ...         ...               ...        ...
# 162758                   ITA                                    7×15+
# 162759                   USA                                    5×15+
# 162760                   ITA                                    8×16+
# 162761                   USA                                    9×17+
# 162762                   AUT
#
#        value_type
# 0
# 1
# 2
# 3
# 4
# ...           ...
# 162758       RANK
# 162759       RANK
# 162760       RANK
# 162761       RANK
# 162762        IRM
#
# [7976 rows x 15 columns]

# %% [markdown]
# Se observa diferencia de formato la columna athletes

# %%
def identificar_tipos(df, column_name):
    """
    Identifica y resume los tipos de datos de los elementos en una columna.

    Args:
        df (pd.DataFrame): DataFrame que contiene la columna.
        column_name (str): Nombre de la columna a inspeccionar.
    """
    types_summary = df[column_name].apply(lambda x: type(x).__name__).value_counts()
    print(f"Resumen de tipos de datos en la columna '{column_name}':")
    print(types_summary)

# %%
identificar_tipos(df_csv_aligned, 'athletes')
# Out:
# Resumen de tipos de datos en la columna 'athletes':
# athletes
# str    162804
# Name: count, dtype: int64

# %%
identificar_tipos(df_pkl_aligned, 'athletes')
# Out:
# Resumen de tipos de datos en la columna 'athletes':
# athletes
# str     154828
# list      7976
# Name: count, dtype: int64

# %%
import ast

def convertir_string_a_list(x):
    """
    Convierte strings que representan listas o tuplas a objetos reales.
    """
    try:
        return ast.literal_eval(x)
    except (ValueError, SyntaxError):
        return x

# %%
# Aplicar la función a la columna athletes proveniente del csv
df_csv_aligned['athletes_converted'] = df_csv_aligned['athletes'].apply(convertir_string_a_list)

# %%
identificar_tipos(df_csv_aligned, 'athletes_converted')
# Out:
# Resumen de tipos de datos en la columna 'athletes_converted':
# athletes_converted
# str     154828
# list      7976
# Name: count, dtype: int64

# %%
df_csv_aligned['athletes'] = df_csv_aligned['athletes_converted']

# %%
df_csv_aligned = df_csv_aligned.drop(columns=['athletes_converted'])

# %%
comparar_columnas(df_csv_aligned, df_pkl_aligned)
# Out:
# La columna 'discipline_title' es idéntica en ambos DataFrames.
# La columna 'event_title' es idéntica en ambos DataFrames.
# La columna 'slug_game' es idéntica en ambos DataFrames.
# La columna 'participant_type' es idéntica en ambos DataFrames.
# La columna 'medal_type' es idéntica en ambos DataFrames.
# La columna 'athletes' es idéntica en ambos DataFrames.
# La columna 'rank_equal' es idéntica en ambos DataFrames.
# La columna 'rank_position' es idéntica en ambos DataFrames.
# La columna 'country_name' es idéntica en ambos DataFrames.
# La columna 'country_code' es idéntica en ambos DataFrames.
# La columna 'country_3_letter_code' es idéntica en ambos DataFrames.
# La columna 'athlete_url' es idéntica en ambos DataFrames.
# La columna 'athlete_full_name' es idéntica en ambos DataFrames.
# La columna 'value_unit' es idéntica en ambos DataFrames.
# La columna 'value_type' es idéntica en ambos DataFrames.

# %% [markdown]
# Confirmamos que los datos de estos archivos coinciden, y optamos por usar la versión PKL para evitar el error con el país "Namibia".

# %%
# df_pkl.to_csv('datos/raw/olympic_results_from_pkl.csv')

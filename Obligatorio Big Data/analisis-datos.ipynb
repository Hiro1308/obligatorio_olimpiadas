# %%
import pandas as pd
# Cargamos los archivos
df_athletes = pd.read_csv('./datos/olympic_athletes.csv')
df_hosts = pd.read_csv('./datos/olympic_hosts.csv')
df_medals = pd.read_csv('./datos/olympic_medals.csv')
df_results = pd.read_csv('./datos/olympic_results.csv')


# Hacemos una función para mostrar información básica de cada DataFrame
def analizar_dataset(df, nombre):
    print(f"--- Dataset: {nombre} ---")
    print("Primeras rows:")
    display(df.head())

    print(f"\nInformación básica del DataFrame: {nombre}")
    df.info()

    print("\nDescripción estadística:")
    display(df.describe(include='all'))

    print("\nValores nulos por columna:")
    display(df.isnull().sum())

    print("\nRegistros duplicados:")
    display(df.duplicated().sum())

    print("\nColumnas:")
    for col in df.columns:
        print(col)
    print("\n\n")


# Ejecutamos la función por cada uno de los datasets
analizar_dataset(df_athletes, 'Atletas')
analizar_dataset(df_hosts, 'Hosts')
analizar_dataset(df_medals, 'Medallas')
analizar_dataset(df_results, 'Resultados')
# Out:
# --- Dataset: Atletas ---
# Primeras rows:
#                                          athlete_url       athlete_full_name  \
# 0  https://olympics.com/en/athletes/cooper-woods-...  Cooper WOODS-TOPALOVIC
# 1          https://olympics.com/en/athletes/elofsson          Felix ELOFSSON
# 2     https://olympics.com/en/athletes/dylan-walczyk           Dylan WALCZYK
# 3     https://olympics.com/en/athletes/olli-penttala           Olli PENTTALA
# 4          https://olympics.com/en/athletes/reikherd        Dmitriy REIKHERD
#
#    games_participations        first_game  athlete_year_birth athlete_medals  \
# 0                     1      Beijing 2022              2000.0            NaN
# 1                     2  PyeongChang 2018              1995.0            NaN
# 2                     1      Beijing 2022              1993.0            NaN
# 3                     1      Beijing 2022              1995.0            NaN
# 4                     1      Beijing 2022              1989.0            NaN
# ...

# %%
import pandas as pd

# Cargamos los archivos
df_athletes = pd.read_csv('./datos/olympic_athletes.csv')
df_hosts = pd.read_csv('./datos/olympic_hosts.csv')
df_medals = pd.read_csv('./datos/olympic_medals.csv')
df_results = pd.read_csv('./datos/olympic_results.csv')

def spacer():
    print("\n\n")
    print("===============================================")
    print("\n\n")


# Hacemos una función para mostrar información básica de cada DataFrame
def analizar_dataset(df, nombre):
    print(f"--- Dataset: {nombre} ---")
    print("Primeras rows:")
    display(df.head())

    spacer()

    print(f"\nInformación básica del DataFrame: {nombre}")
    df.info()

    spacer()

    print("\nDescripción estadística:")
    display(df.describe(include='all'))

    spacer()

    print("\nValores nulos por columna:")
    display(df.isnull().sum())

    spacer()

    print("\nRegistros duplicados:")
    display(df.duplicated().sum())

    spacer()

    print("\nColumnas:")
    for col in df.columns:
        print(col)

    spacer()


# Ejecutamos la función por cada uno de los datasets
analizar_dataset(df_athletes, 'Atletas')
analizar_dataset(df_hosts, 'Hosts')
analizar_dataset(df_medals, 'Medallas')
analizar_dataset(df_results, 'Resultados')
# Out:
# --- Dataset: Atletas ---
# Primeras rows:
#                                          athlete_url       athlete_full_name  \
# 0  https://olympics.com/en/athletes/cooper-woods-...  Cooper WOODS-TOPALOVIC
# 1          https://olympics.com/en/athletes/elofsson          Felix ELOFSSON
# 2     https://olympics.com/en/athletes/dylan-walczyk           Dylan WALCZYK
# 3     https://olympics.com/en/athletes/olli-penttala           Olli PENTTALA
# 4          https://olympics.com/en/athletes/reikherd        Dmitriy REIKHERD
#
#    games_participations        first_game  athlete_year_birth athlete_medals  \
# 0                     1      Beijing 2022              2000.0            NaN
# 1                     2  PyeongChang 2018              1995.0            NaN
# 2                     1      Beijing 2022              1993.0            NaN
# 3                     1      Beijing 2022              1995.0            NaN
# 4                     1      Beijing 2022              1989.0            NaN
# ...

# %%
def limpiar_datos(df):
    # Eliminamos filas con valores nulos
    df.dropna(inplace=True)
    # Llenamos valores nulos con 0 (o cualquier otro valor)
    df.fillna(0, inplace=True)

# Limpiamos todos los Dataframes y los guardamos en unos nuevos
df_athletes_clean = limpiar_datos(df_athletes)
df_hosts_clean = limpiar_datos(df_hosts)
df_medals_clean = limpiar_datos(df_medals)
df_results_clean = limpiar_datos(df_results)

# Guardamos los DataFrames limpios en otra carpeta
df_athletes_clean.to_csv('./datos_clean/olympic_athlete.csv', index=False)
df_hosts_clean.to_csv('./datos_clean/olympic_hosts.csv', index=False)
df_medals_clean.to_csv('./datos_clean/olympic_medals.csv', index=False)
df_results_clean.to_csv('./datos_clean/olympic_results.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 14
#      11 df_results_clean = limpiar_datos(df_results)
#      13 # Guardamos los DataFrames limpios en otra carpeta
# ---> 14 df_athletes_clean.to_csv('./datos_clean/olympic_athlete.csv', index=False)
#      15 df_hosts_clean.to_csv('./datos_clean/olympic_hosts.csv', index=False)
#      16 df_medals_clean.to_csv('./datos_clean/olympic_medals.csv', index=False)
#
# AttributeError: 'NoneType' object has no attribute 'to_csv'

# %%
# Cargamos los archivos
df_athletes = pd.read_csv('./datos_clean/olympic_athletes.csv')
df_hosts = pd.read_csv('./datos_clean/olympic_hosts.csv')
df_medals = pd.read_csv('./datos_clean/olympic_medals.csv')
df_results = pd.read_csv('./datos_clean/olympic_results.csv')

def spacer():
    print("\n\n")
    print("===============================================")
    print("\n\n")


# Hacemos una función para mostrar información básica de cada DataFrame
def analizar_dataset(df, nombre):
    print(f"====== Dataset: {nombre} ======")
    print("Primeras rows:")
    display(df.head())

    spacer()

    print(f"\nInformación básica del DataFrame: {nombre}")
    df.info()

    spacer()

    print("\nDescripción estadística:")
    display(df.describe(include='all'))

    spacer()

    print("\nValores nulos por columna:")
    display(df.isnull().sum())

    spacer()

    print("\nRegistros duplicados:")
    display(df.duplicated().sum())

    spacer()

    print("\nColumnas:")
    for col in df.columns:
        print(col)

    spacer()


# Ejecutamos la función por cada uno de los datasets
analizar_dataset(df_athletes, 'Atletas')
analizar_dataset(df_hosts, 'Hosts')
analizar_dataset(df_medals, 'Medallas')
analizar_dataset(df_results, 'Resultados')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Cargamos los archivos
# ----> 2 df_athletes = pd.read_csv('./datos_clean/olympic_athletes.csv')
#       3 df_hosts = pd.read_csv('./datos_clean/olympic_hosts.csv')
#       4 df_medals = pd.read_csv('./datos_clean/olympic_medals.csv')
#
# ...

# %%
# Cargamos los archivos
df_athletes = pd.read_csv('./datos_clean/olympic_athletes.csv')
df_hosts = pd.read_csv('./datos_clean/olympic_hosts.csv')
df_medals = pd.read_csv('./datos_clean/olympic_medals.csv')
df_results = pd.read_csv('./datos_clean/olympic_results.csv')

def spacer():
    print("\n\n")
    print("===============================================")
    print("\n\n")


# Hacemos una función para mostrar información básica de cada DataFrame
def analizar_dataset(df, nombre):
    print(f"====== Dataset: {nombre} ======")
    print("Primeras rows:")
    display(df.head())

    spacer()

    print(f"\nInformación básica del DataFrame: {nombre}")
    df.info()

    spacer()

    print("\nDescripción estadística:")
    display(df.describe(include='all'))

    spacer()

    print("\nValores nulos por columna:")
    display(df.isnull().sum())

    spacer()

    print("\nRegistros duplicados:")
    display(df.duplicated().sum())

    spacer()

    print("\nColumnas:")
    for col in df.columns:
        print(col)

    spacer()


# Ejecutamos la función por cada uno de los datasets
analizar_dataset(df_athletes, 'Atletas')
analizar_dataset(df_hosts, 'Hosts')
analizar_dataset(df_medals, 'Medallas')
analizar_dataset(df_results, 'Resultados')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[14], line 2
#       1 # Cargamos los archivos
# ----> 2 df_athletes = pd.read_csv('./datos_clean/olympic_athletes.csv')
#       3 df_hosts = pd.read_csv('./datos_clean/olympic_hosts.csv')
#       4 df_medals = pd.read_csv('./datos_clean/olympic_medals.csv')
#
# ...

# %%
# Cargamos los archivos
df_athletes = pd.read_csv('/datos_clean/olympic_athletes.csv')
df_hosts = pd.read_csv('/datos_clean/olympic_hosts.csv')
df_medals = pd.read_csv('/datos_clean/olympic_medals.csv')
df_results = pd.read_csv('/datos_clean/olympic_results.csv')

def spacer():
    print("\n\n")
    print("===============================================")
    print("\n\n")


# Hacemos una función para mostrar información básica de cada DataFrame
def analizar_dataset(df, nombre):
    print(f"====== Dataset: {nombre} ======")
    print("Primeras rows:")
    display(df.head())

    spacer()

    print(f"\nInformación básica del DataFrame: {nombre}")
    df.info()

    spacer()

    print("\nDescripción estadística:")
    display(df.describe(include='all'))

    spacer()

    print("\nValores nulos por columna:")
    display(df.isnull().sum())

    spacer()

    print("\nRegistros duplicados:")
    display(df.duplicated().sum())

    spacer()

    print("\nColumnas:")
    for col in df.columns:
        print(col)

    spacer()


# Ejecutamos la función por cada uno de los datasets
analizar_dataset(df_athletes, 'Atletas')
analizar_dataset(df_hosts, 'Hosts')
analizar_dataset(df_medals, 'Medallas')
analizar_dataset(df_results, 'Resultados')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[15], line 2
#       1 # Cargamos los archivos
# ----> 2 df_athletes = pd.read_csv('/datos_clean/olympic_athletes.csv')
#       3 df_hosts = pd.read_csv('/datos_clean/olympic_hosts.csv')
#       4 df_medals = pd.read_csv('/datos_clean/olympic_medals.csv')
#
# ...

# %%
# Cargamos los archivos
df_athletes = pd.read_csv('datos_clean/olympic_athletes.csv')
df_hosts = pd.read_csv('datos_clean/olympic_hosts.csv')
df_medals = pd.read_csv('datos_clean/olympic_medals.csv')
df_results = pd.read_csv('datos_clean/olympic_results.csv')

def spacer():
    print("\n\n")
    print("===============================================")
    print("\n\n")


# Hacemos una función para mostrar información básica de cada DataFrame
def analizar_dataset(df, nombre):
    print(f"====== Dataset: {nombre} ======")
    print("Primeras rows:")
    display(df.head())

    spacer()

    print(f"\nInformación básica del DataFrame: {nombre}")
    df.info()

    spacer()

    print("\nDescripción estadística:")
    display(df.describe(include='all'))

    spacer()

    print("\nValores nulos por columna:")
    display(df.isnull().sum())

    spacer()

    print("\nRegistros duplicados:")
    display(df.duplicated().sum())

    spacer()

    print("\nColumnas:")
    for col in df.columns:
        print(col)

    spacer()


# Ejecutamos la función por cada uno de los datasets
analizar_dataset(df_athletes, 'Atletas')
analizar_dataset(df_hosts, 'Hosts')
analizar_dataset(df_medals, 'Medallas')
analizar_dataset(df_results, 'Resultados')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[16], line 2
#       1 # Cargamos los archivos
# ----> 2 df_athletes = pd.read_csv('datos_clean/olympic_athletes.csv')
#       3 df_hosts = pd.read_csv('datos_clean/olympic_hosts.csv')
#       4 df_medals = pd.read_csv('datos_clean/olympic_medals.csv')
#
# ...

# %%
# Cargamos los archivos
df_athletes = pd.read_csv('./datos_clean/olympic_athletes.csv')
df_hosts = pd.read_csv('./datos_clean/olympic_hosts.csv')
df_medals = pd.read_csv('./datos_clean/olympic_medals.csv')
df_results = pd.read_csv('./datos_clean/olympic_results.csv')

def spacer():
    print("\n\n")
    print("===============================================")
    print("\n\n")


# Hacemos una función para mostrar información básica de cada DataFrame
def analizar_dataset(df, nombre):
    print(f"====== Dataset: {nombre} ======")
    print("Primeras rows:")
    display(df.head())

    spacer()

    print(f"\nInformación básica del DataFrame: {nombre}")
    df.info()

    spacer()

    print("\nDescripción estadística:")
    display(df.describe(include='all'))

    spacer()

    print("\nValores nulos por columna:")
    display(df.isnull().sum())

    spacer()

    print("\nRegistros duplicados:")
    display(df.duplicated().sum())

    spacer()

    print("\nColumnas:")
    for col in df.columns:
        print(col)

    spacer()


# Ejecutamos la función por cada uno de los datasets
analizar_dataset(df_athletes, 'Atletas')
analizar_dataset(df_hosts, 'Hosts')
analizar_dataset(df_medals, 'Medallas')
analizar_dataset(df_results, 'Resultados')
# Out:
# ====== Dataset: Atletas ======
# Primeras rows:
#                                          athlete_url      athlete_full_name  \
# 0  https://olympics.com/en/athletes/mikael-kingsbury       Mikael KINGSBURY
# 1        https://olympics.com/en/athletes/david-wise             David WISE
# 2     https://olympics.com/en/athletes/gus-kenworthy          Gus KENWORTHY
# 3  https://olympics.com/en/athletes/jean-frederic...  Jean Frederic CHAPUIS
# 4  https://olympics.com/en/athletes/gu-ailing-eileen       Ailing Eileen GU
#
#    games_participations    first_game  athlete_year_birth  \
# 0                     3    Sochi 2014              1992.0
# 1                     3    Sochi 2014              1990.0
# 2                     3    Sochi 2014              1991.0
# 3                     3    Sochi 2014              1989.0
# 4                     1  Beijing 2022              2003.0
#
#                    athlete_medals  \
# 0  \n\n\n1\n\nG\n\n\n\n2\n\nS\n\n
# 1  \n\n\n2\n\nG\n\n\n\n1\n\nS\n\n
# ...
